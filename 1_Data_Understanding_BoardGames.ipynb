# %% [markdown]
# ## 1. Data Understanding
#
#
# In this Notebook we carry out a brief analysis of the Board Games Dataset.
#
# The objective is to familiarize ourselves with the content and to know each one of the variables that the dataset presents.

# %% [markdown]
# #### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
pd.options.display.max_columns = None

# %% [markdown]
# #### Read Board Games data

# %%
# %cd /Users/postigo/Documents/20200702_DatasetTFM/20200705_Notebooks/Data
# Out:
# /Users/postigo/Documents/20200702_DatasetTFM/20200705_Notebooks/Data

# %%
df=pd.read_csv("bgg_GameItem.csv")

# %%
df.head(10)
# Out:
#    bgg_id                name    year game_type designer       artist  \
# 0       1          Die Macher  1986.0      5497        1   12517,4959
# 1       2        Dragonmaster  1981.0      5497     8384        12424
# 2       3             Samurai  1998.0      5497        2        11883
# 3       4      Tal der Könige  1992.0       NaN     8008         2277
# 4       5             Acquire  1964.0      5497        4  12658,18317
# 5       6  Mare Mediterraneum  1989.0       NaN        5            5
# 6       7           Cathedral  1978.0      4666     1335        36624
# 7       8   Lords of Creation  1993.0       NaN        6        36807
# 8       9        El Caballero  1998.0      5497      7,8           74
# 9      10           Elfenland  1998.0      5499        9           74
#
#                                            publisher  min_players  \
# 0             133,2,2726,15108,39249,11652,5382,8147          3.0
# ...

# %%
print('Number rows and columns', df.shape)
# Out:
# Number rows and columns (95254, 38)

# %%
columns= list(df.columns)
columns
# Out:
# ['bgg_id',
#  'name',
#  'year',
#  'game_type',
#  'designer',
#  'artist',
#  'publisher',
#  'min_players',
#  'max_players',
#  'min_players_rec',
#  'max_players_rec',
#  'min_players_best',
#  'max_players_best',
#  'min_age',
#  'min_age_rec',
#  'min_time',
#  'max_time',
#  'category',
#  'mechanic',
#  'cooperative',
#  'compilation',
#  'compilation_of',
#  'family',
#  'implementation',
#  'integration',
#  'rank',
#  'num_votes',
#  'avg_rating',
#  'stddev_rating',
#  'bayes_rating',
#  'complexity',
#  'language_dependency',
#  'bga_id',
#  'dbpedia_id',
#  'luding_id',
#  'spielen_id',
#  'wikidata_id',
#  'wikipedia_id']

# %%
# Data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95254 entries, 0 to 95253
# Data columns (total 38 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   bgg_id               95254 non-null  int64
#  1   name                 95254 non-null  object
#  2   year                 86429 non-null  float64
#  3   game_type            20962 non-null  object
#  4   designer             81879 non-null  object
#  5   artist               38181 non-null  object
#  6   publisher            95243 non-null  object
#  7   min_players          93399 non-null  float64
#  8   max_players          89888 non-null  float64
#  9   min_players_rec      93399 non-null  float64
#  10  max_players_rec      89888 non-null  float64
#  11  min_players_best     93399 non-null  float64
#  12  max_players_best     89888 non-null  float64
#  13  min_age              73676 non-null  float64
#  14  min_age_rec          834 non-null    float64
# ...

# %%
# Quick overview of values
df.describe(include='all')
# Out:
#                bgg_id        name          year game_type designer artist  \
# count    95254.000000       95254  86429.000000     20962    81879  38181
# unique            NaN       90979           NaN        40    27111  17904
# top               NaN  Grand Prix           NaN      4664        3      3
# freq              NaN          12           NaN      7328    18650   3704
# mean    118223.165757         NaN   1998.654433       NaN      NaN    NaN
# std      97450.094613         NaN     71.628895       NaN      NaN    NaN
# min          1.000000         NaN  -3500.000000       NaN      NaN    NaN
# 25%      27393.250000         NaN   1994.000000       NaN      NaN    NaN
# 50%     102035.500000         NaN   2008.000000       NaN      NaN    NaN
# 75%     196544.250000         NaN   2015.000000       NaN      NaN    NaN
# max     313274.000000         NaN   2022.000000       NaN      NaN    NaN
#
#        publisher   min_players   max_players  min_players_rec  \
# ...

# %%
df['bgg_id'].value_counts()
# Out:
# 2047      1
# 45827     1
# 223992    1
# 301541    1
# 226043    1
#          ..
# 5608      1
# 7657      1
# 1514      1
# 3563      1
# 262144    1
# Name: bgg_id, Length: 95254, dtype: int64

# %%
# Null values for each column
df.isnull().sum()
# Out:
# bgg_id                     0
# name                       0
# year                    8825
# game_type              74292
# designer               13375
# artist                 57073
# publisher                 11
# min_players             1855
# max_players             5366
# min_players_rec         1855
# max_players_rec         5366
# min_players_best        1855
# max_players_best        5366
# min_age                21578
# min_age_rec            94420
# min_time               20099
# max_time               20099
# category                1948
# mechanic               15219
# cooperative                0
# compilation                0
# compilation_of         94679
# family                 42157
# implementation         91113
# integration            92516
# rank                   76167
# num_votes                  0
# avg_rating             25432
# stddev_rating              0
# bayes_rating           75913
# complexity             54182
# language_dependency    94493
# ...

# %%
# Delete columns with all null values
df.drop(columns = ['bga_id','dbpedia_id','luding_id','spielen_id','wikidata_id','wikipedia_id'], inplace=True)
df.columns
# Out:
# Index(['bgg_id', 'name', 'year', 'game_type', 'designer', 'artist',
#        'publisher', 'min_players', 'max_players', 'min_players_rec',
#        'max_players_rec', 'min_players_best', 'max_players_best', 'min_age',
#        'min_age_rec', 'min_time', 'max_time', 'category', 'mechanic',
#        'cooperative', 'compilation', 'compilation_of', 'family',
#        'implementation', 'integration', 'rank', 'num_votes', 'avg_rating',
#        'stddev_rating', 'bayes_rating', 'complexity', 'language_dependency'],
#       dtype='object')

# %%
# Categorical variables
df['cooperative'].value_counts()
# Out:
# 0    90779
# 1     4475
# Name: cooperative, dtype: int64

# %%
sns.boxplot(x="cooperative", y="rank", data=df)

# %%
# Check if there is a correlation between the data

f, ax = plt.subplots(figsize=(12, 8))
corr = df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(240, 10, as_cmap=True),
               square=True, ax=ax)

# %%
# Order the dataset according to the rank column
rank = df.sort_values('rank')
rank.head(10)
# Out:
#        bgg_id                                           name    year  \
# 66090  174430                                     Gloomhaven  2017.0
# 62878  161936                      Pandemic Legacy: Season 1  2015.0
# 76339  224517                              Brass: Birmingham  2018.0
# 64259  167791                              Terraforming Mars  2016.0
# 68241  182028  Through the Ages: A New Story of Civilization  2015.0
# 78218  233078             Twilight Imperium (Fourth Edition)  2017.0
# 69555  187645                           Star Wars: Rebellion  2016.0
# 75669  220308                                   Gaia Project  2017.0
# 10824   12333                              Twilight Struggle  2005.0
# 70890  193738                            Great Western Trail  2016.0
#
#        game_type       designer  \
# 66090  5496,5497          69802
# 62878  5496,5497        442,378
# 76339       5497  32887,32943,6
# 64259       5497          52075
# 68241       5497            789
# ...

# %%
# Order the dataset according to the year column and brief analysis
year = df.sort_values('year', ascending=False)
year.head(50)
# Out:
#        bgg_id                                             name    year  \
# 90902  294274                                    La Dolce Vita  2022.0
# 93663  305992                                   Hostage Crisis  2022.0
# 87358  277670                                M: Secret Society  2022.0
# 86745  274512                                        Hindsight  2022.0
# 92217  299604                      Aldabas: Doors of Cartagena  2022.0
# 94320  308846                          Jackpot! Break the Bank  2022.0
# 87787  279876                                  Template of War  2022.0
# 81145  247767                                 Boogeynoris Wine  2022.0
# 74100  210206                                    Transhumanity  2022.0
# 93568  305353                                           Clutch  2022.0
# 86146  270871                                         Agemonia  2022.0
# 93036  302679                       Stormsunder: Heirs of Ruin  2022.0
# ...

# %%
year['year'][year['year'].isin([2021, 2022])].count()
# Out:
# 274

# %%
year['year'][year['year']==2020].count()
# Out:
# 2793

# %%
year.tail(50)
# Out:
#        bgg_id                                        name  year game_type  \
# 94505  309761                Woody Woodpecker wird gejagt   NaN       NaN
# 94520  309827                                  Glass Bead   NaN       NaN
# 94531  309852          The Treasure of Montecristo Island   NaN       NaN
# 94539  309866                              Secret Sinners   NaN       NaN
# 94545  309883                                 Veggie Loto   NaN       NaN
# 94553  309893                   Hostile Environment: Walk   NaN       NaN
# 94587  310025                                      Alpina   NaN       NaN
# 94593  310055                                Restaurounds   NaN       NaN
# 94595  310065         Herra Hakkaraisen seitsemän ihmettä   NaN       NaN
# 94664  310306                                    Oymyakon   NaN       NaN
# 94669  310333                                Carpet Bocce   NaN       NaN
# 94694  310449                                     Venedig   NaN       NaN
# ...

# %%
year['year'].isnull().sum()
# Out:
# 8825

# %%
year['year'][year['year'].isin([-3500, -3000])].count()
# Out:
# 6

# %%
year[year['name']=='Catan']
# Out:
#     bgg_id   name    year  game_type designer  \
# 12      13  Catan  1995.0  5497,5499       11
#
#                                                artist  \
# 12  12036,12382,13034,5442,26874,4959,11825,24191,...
#
#                                             publisher  min_players  \
# 12  37,267,4304,7340,6784,7162,4358,31418,4335,496...          3.0
#
#     max_players  min_players_rec  max_players_rec  min_players_best  \
# 12          4.0              3.0              4.0               4.0
#
#     max_players_best  min_age  min_age_rec  min_time  max_time   category  \
# 12               4.0     10.0     8.362162      60.0     120.0  1021,1026
#
#                                         mechanic  cooperative  compilation  \
# 12  2072,2026,2902,2011,2081,2876,2909,2008,2897            0            0
#
#    compilation_of   family implementation integration   rank  num_votes  \
# 12            NaN  3,11505            NaN         NaN  370.0      94774
#
# ...

# %%
year[year['year']>=1995]
# Out:
#        bgg_id                                               name    year  \
# 90902  294274                                      La Dolce Vita  2022.0
# 93663  305992                                     Hostage Crisis  2022.0
# 87358  277670                                  M: Secret Society  2022.0
# 86745  274512                                          Hindsight  2022.0
# 92217  299604                        Aldabas: Doors of Cartagena  2022.0
# ...       ...                                                ...     ...
# 28753   33058                             My First Matching Game  1995.0
# 790       910                                       Kunst Stücke  1995.0
# 2856     3315                          Die LeuchtturmArchitekten  1995.0
# 35128   40445                               Pursuit of Happiness  1995.0
# 2636     3070  Red Parachutes: Soviet Airborne Assault Across...  1995.0
#
#       game_type     designer           artist publisher  min_players  \
# ...

# %%
year['year'][year['year']<1995].count()
# Out:
# 22199

# %%
year['year'][year['year']>=1995].count()
# Out:
# 64230

# %%
year[year['year']>=1995].isnull().sum()
# Out:
# bgg_id                     0
# name                       0
# year                       0
# game_type              50764
# designer                7505
# artist                 32479
# publisher                  9
# min_players              594
# max_players             2525
# min_players_rec          594
# max_players_rec         2525
# min_players_best         594
# max_players_best        2525
# min_age                10194
# min_age_rec            63506
# min_time                9136
# max_time                9136
# category                1226
# mechanic                9037
# cooperative                0
# compilation                0
# compilation_of         63756
# family                 26830
# implementation         60554
# integration            61697
# rank                   48659
# num_votes                  0
# avg_rating             13743
# stddev_rating              0
# bayes_rating           48438
# complexity             33012
# language_dependency    63558
# ...
