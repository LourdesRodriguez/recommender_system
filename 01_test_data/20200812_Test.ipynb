# %%
import pandas as pd
from rake_nltk import Rake
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# %%
folder= './Data'

# %%
df_game = pd.read_csv(folder+'/BggGames.csv')

df_game.head(10)
# Out:
#    bgg_id                name    year game_type designer       artist  \
# 0       1          Die Macher  1986.0      5497        1   12517,4959
# 1       2        Dragonmaster  1981.0      5497     8384        12424
# 2       3             Samurai  1998.0      5497        2        11883
# 3       4      Tal der Könige  1992.0       NaN     8008         2277
# 4       5             Acquire  1964.0      5497        4  12658,18317
# 5       6  Mare Mediterraneum  1989.0       NaN        5            5
# 6       7           Cathedral  1978.0      4666     1335        36624
# 7       8   Lords of Creation  1993.0       NaN        6        36807
# 8       9        El Caballero  1998.0      5497      7,8           74
# 9      10           Elfenland  1998.0      5499        9           74
#
#                                            publisher  min_players  \
# 0             133,2,2726,15108,39249,11652,5382,8147          3.0
# ...

# %%
df_game= df_game.sort_values('rank')
df_game.head
(50)
# Out:
#        bgg_id                                               name    year  \
# 95480  314079                                           Galamons  2020.0
# 95481  314080        Your Quest, Should You Choose to Accept It!  2020.0
# 95482  314081                           おとひめクエスト (Otohime Quest)  2015.0
# 95483  314086                            First Monday in October  2021.0
# 95484  314088                                          Agropolis  2020.0
# 95485  314113                      落書きプラネット (Rakugaki Puranetto)  2012.0
# 95486  314126                                Clue: Downton Abbey  2019.0
# 95487  314169                                         Crossroads  2020.0
# 95488  314170                              2 Minutes to Midnight  2021.0
# 95489  314171                              Dive Master Card Game  2020.0
# 95490  314172                                        Battle Peak  2021.0
# 95491  314174                                   Disaster Blaster  2020.0
# ...

# %%
df_game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95530 entries, 66090 to 95529
# Data columns (total 38 columns):
# bgg_id                 95530 non-null int64
# name                   95530 non-null object
# year                   86698 non-null float64
# game_type              20987 non-null object
# designer               82110 non-null object
# artist                 38370 non-null object
# publisher              95520 non-null object
# min_players            93686 non-null float64
# max_players            90176 non-null float64
# min_players_rec        93686 non-null float64
# max_players_rec        90176 non-null float64
# min_players_best       93686 non-null float64
# max_players_best       90176 non-null float64
# min_age                73935 non-null float64
# min_age_rec            843 non-null float64
# min_time               75400 non-null float64
# max_time               75400 non-null float64
# category               93578 non-null object
# ...

# %%
df_rank = pd.read_csv(folder+'/BggGames.csv', usecols= ['bgg_id','name','category','mechanic','rank'])
df_rank.head(10)
# Out:
#    bgg_id                name        category                       mechanic  \
# 0       1          Die Macher  1021,1026,1001  2916,2080,2012,2072,2040,2020
# 1       2        Dragonmaster       1002,1010                           2009
# 2       3             Samurai       1009,1035            2080,2040,2004,2002
# 3       4      Tal der Könige            1050            2001,2080,2012,2004
# 4       5             Acquire            1021  2040,2910,2900,2911,2005,2002
# 5       6  Mare Mediterraneum       1015,1008                           2072
# 6       7           Cathedral            1009            2043,2048,2060,2002
# 7       8   Lords of Creation       1015,1010                           2011
# 8       9        El Caballero            1020                      2080,2002
# 9      10           Elfenland       1010,1097            2041,2040,2081,2078
#
#      rank
# 0   262.0
# 1  3473.0
# 2   199.0
# 3  4584.0
# 4   254.0
# 5  9415.0
# 6  1776.0
# 7  7799.0
# 8  2521.0
# ...

# %%
df_rank.describe()
# Out:
#               bgg_id          rank
# count   95530.000000  19150.000000
# mean   118786.068827   9576.023864
# std     97873.192203   5528.783114
# min         1.000000      1.000000
# 25%     27467.250000   4789.250000
# 50%    102791.500000   9578.000000
# 75%    197823.000000  14360.750000
# max    314730.000000  19178.000000

# %%
df_rank[df_rank['rank']<= 19178]
# Out:
#        bgg_id                              name                  category  \
# 0           1                        Die Macher            1021,1026,1001
# 1           2                      Dragonmaster                 1002,1010
# 2           3                           Samurai                 1009,1035
# 3           4                    Tal der Könige                      1050
# 4           5                           Acquire                      1021
# ...       ...                               ...                       ...
# 94264  308565                       Roll n Cook                      1120
# 94348  308989                      Bristol 1350  1039,1017,1035,1030,1031
# 94607  310100                 Nemesis: Lockdown       1022,1024,1047,1016
# 95212  312804                          Pendulum                      1021
# 95424  313850  Escape The Night: The Board Game  1022,1010,1024,1064,1026
#
#                                       mechanic     rank
# ...

# %%
nan_rows = df_rank[df_rank.isnull().any(1)]
nan_rows
# Out:
#        bgg_id                                    name             category  \
# 20         21                    Gateway to the Stars  1015,1020,1016,1019
# 31         32                           Buffalo Chess            1009,1055
# 34         37                          Dragon Masters            1010,1019
# 35         38                                   Runes            1039,1025
# 36         39                                Darkover       1023,1010,1093
# ...       ...                                     ...                  ...
# 95525  314580                                 Hamburg       1002,1029,1021
# 95526  314582                               Amsterdam                 1017
# 95527  314671  Give Me the Brain: Superdeluxe Edition       1002,1079,2481
# 95528  314672            Stilicho: Last of the Romans            1050,1019
# 95529  314730                                 더 갤러리스트                 1021
#
#                                  mechanic     rank
# ...

# %%
nan_rows_cat = nan_rows[nan_rows['category'].isnull()]
nan_rows_cat
# Out:
#        bgg_id                           name category  \
# 456       518                  Cat vs. Mouse      NaN
# 523       600                Die Weinhändler      NaN
# 755       868                       Atlantis      NaN
# 760       873                        Offline      NaN
# 790       910                   Kunst Stücke      NaN
# ...       ...                            ...      ...
# 95470  314032   Levitation: Masters of Magic      NaN
# 95471  314040      Pandemic Legacy: Season 0      NaN
# 95485  314113  落書きプラネット (Rakugaki Puranetto)      NaN
# 95513  314503                CODEX Naturalis      NaN
# 95521  314546                         Gelato      NaN
#
#                                  mechanic     rank
# 456                                   NaN      NaN
# 523                        2040,2007,2078  17249.0
# 755                                   NaN      NaN
# 760                                  2002  14503.0
# 790                        2676,2040,2002   6811.0
# ...
